# %%
import numpy as np
import pandas as pd
from sklearn.multiclass import OneVsRestClassifier
from sklearn.model_selection import cross_val_score, train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.linear_model import SGDClassifier
from sklearn.metrics import classification_report
from sklearn.model_selection import GridSearchCV
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import Pipeline

# %%
df=pd.read_csv("final.csv",index_col=0)

# %%
df.drop(['Lyrics','Scale'],axis=1,inplace=True)
df
# Out:
#         Genre                 Title        Artist  Explicit  Length    Key  \
# 0        rock        into the storm        gojira     False    5.02  Major
# 1        rock  the sound of silence     disturbed     False    4.08  Minor
# 2        rock              amazonia        gojira     False    5.00  Major
# 3        rock         back in black         ac/dc     False    4.15  Major
# 4        rock         another world        gojira     False    4.24  Minor
# ...       ...                   ...           ...       ...     ...    ...
# 11398  hiphop           let me know       cam'ron      True    4.14  Major
# 11399  hiphop      lyrical gangbang       dr. dre      True    4.04  Major
# 11400  hiphop       just like candy  8-ball & mjg      True    4.19  Major
# 11401  hiphop                  beta   tyson james     False    3.54  Major
# 11402  hiphop        can't truss it  public enemy      True    5.21  Major
#
# ...

# %%
X=df.drop(columns=['Genre'])
y=df['Genre']
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

# %%
text_mnb = MultinomialNB().fit(X_train, y_train)

# %%
print(text_mnb.score(y=y_test, X=X_test))
preds = text_mnb.predict(y_test)
print(classification_report(y_pred=preds, y_true=y_test))
pd.crosstab(preds,y_test)
